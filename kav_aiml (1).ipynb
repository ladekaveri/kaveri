# %%
import pandas as pd
d=pd.read_csv('/water_potability.csv')
print(d)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
from matplotlib import pyplot as pt
x=d['ph']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Hardness']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Solids']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Chloramines']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Sulfate']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Conductivity']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Organic_carbon']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Trihalomethanes']
y=d['Potability']
pt.plot(x,y)

# %%
from matplotlib import pyplot as pt
x=d['Turbidity']
y=d['Potability']
pt.plot(x,y)

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# Hardness            -0.023915        0.003610        -0.013013  -0.014449
# Solids               0.013831        0.010242        -0.009143   0.019546
# Chloramines         -0.020486       -0.012653         0.017084   0.002363
# Sulfate             -0.016121        0.030831        -0.030274  -0.011187
# Conductivity         1.000000        0.020966         0.001285   0.005798
# Organic_carbon       0.020966        1.000000        -0.013274  -0.027308
# Trihalomethanes      0.001285       -0.013274         1.000000  -0.022145
# Turbidity            0.005798       -0.027308        -0.022145   1.000000
# Potability          -0.008128       -0.030001         0.007130   0.001581
#
#                  Potability
# ph                -0.003556
# Hardness          -0.013837
# Solids             0.033743
# Chloramines        0.023779
# Sulfate           -0.023577
# Conductivity      -0.008128
# Organic_carbon    -0.030001
# Trihalomethanes    0.007130
# Turbidity          0.001581
# Potability         1.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
cov_matrix=d.cov()
print(cov_matrix)
# Out:
#                           ph      Hardness        Solids  Chloramines  \
# ph                  2.541855      4.311552 -1.241574e+03    -0.087082
# Hardness            4.311552   1081.078715 -1.352149e+04    -1.564367
# Solids          -1241.574314 -13521.486526  7.688783e+07  -973.746052
# Chloramines        -0.087082     -1.564367 -9.737461e+02     2.506158
# Sulfate             1.186266   -144.761334 -6.235777e+04     1.787528
# Conductivity        2.402716    -63.552473  9.802117e+03    -2.621264
# Organic_carbon      0.229169      0.392670  2.971084e+02    -0.066268
# Trihalomethanes     0.085900     -6.922214 -1.291069e+03     0.436685
# Turbidity          -0.048879     -0.370747  1.337511e+02     0.002920
# Potability         -0.002773     -0.221943  1.443451e+02     0.018365
#
#                       Sulfate  Conductivity  Organic_carbon  Trihalomethanes  \
# ph                   1.186266      2.402716        0.229169         0.085900
# Hardness          -144.761334    -63.552473        0.392670        -6.922214
# Solids          -62357.772446   9802.117116      297.108377     -1291.069341
# Chloramines          1.787528     -2.621264       -0.066268         0.436685
# Sulfate           1715.354674    -53.930463        4.224945       -20.163481
# Conductivity       -53.930463   6532.529330        5.605967         1.682967
# Organic_carbon       4.224945      5.605967       10.943936        -0.712170
# Trihalomethanes    -20.163481      1.682967       -0.712170       261.630897
# Turbidity           -0.362612      0.365712       -0.070499        -0.278380
# Potability          -0.477408     -0.320499       -0.048419         0.056334
#
#                   Turbidity  Potability
# ph                -0.048879   -0.002773
# Hardness          -0.370747   -0.221943
# Solids           133.751106  144.345121
# Chloramines        0.002920    0.018365
# Sulfate           -0.362612   -0.477408
# Conductivity       0.365712   -0.320499
# Organic_carbon    -0.070499   -0.048419
# Trihalomethanes   -0.278380    0.056334
# Turbidity          0.608997    0.000602
# Potability         0.000602    0.237997

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cov_matrix,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd
d=pd.read_csv('/water_potability.csv')
print(d)
print(d.shape)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]
# (3276, 10)

# %%
x=d.iloc[ :,0:9]
y=d.iloc[ :,9:10]

# %%
print(x)
print(y)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# 1       592.885359       15.180013        56.329076   4.500656
# 2       418.606213       16.868637        66.420093   3.055934
# 3       363.266516       18.436524       100.341674   4.628771
# 4       398.410813       11.558279        31.997993   4.075075
# ...            ...             ...              ...        ...
# 3271    526.424171       13.894419        66.687695   4.435821
# 3272    392.449580       19.903225              NaN   2.798243
# 3273    432.044783       11.039070        69.845400   3.298875
# 3274    402.883113       11.168946        77.488213   4.708658
# 3275    327.459760       16.140368        78.698446   2.309149
#
# [3276 rows x 9 columns]
#       Potability
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3271           1
# 3272           1
# 3273           1
# 3274           1
# 3275           1
#
# [3276 rows x 1 columns]
